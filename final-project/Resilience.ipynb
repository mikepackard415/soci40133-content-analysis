# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_pickle('../Data/Resilience/final.pkl')

# %%
df.head()
# Out:
#                                                   url  \
# 21  https://www.resilience.org/stories/2021-07-12/...
# 22  https://www.resilience.org/stories/2021-07-12/...
# 23  https://www.resilience.org/stories/2021-07-12/...
# 24  https://www.resilience.org/stories/2021-07-12/...
# 25  https://www.resilience.org/stories/2021-07-12/...
#
#                                                 title       date  \
# 21  Scientists Call Northwest Heatwave the ‘Most E... 2021-07-12
# 22       Letter From The Farm | Welcome To The Burren 2021-07-12
# 23  Wisdom Traditions, Science and the Search for ... 2021-07-12
# 24                            Defending Beef: Excerpt 2021-07-12
# 25                                   The show is over 2021-07-12
#
#                   author                                               text  \
# 21          Jake Johnson  Ed. note: This piece was originally published ...
# 22           Shane Casey  Ed. note: This article first appeared on ARC20...
# 23         David Bollier  Jeremy Lent has taken on an audacious task for...
# 24  Nicolette Hahn Niman  The following excerpt is from Nicolette Hahn N...
# 25        Greta Thunberg  Ed. note: This piece was originally published ...
#
#                                             text_list  num_words  month
# 21  [Ed., note:, This, piece, was, originally, pub...        635      7
# 22  [Ed., note:, This, article, first, appeared, o...       1165      7
# 23  [Jeremy, Lent, has, taken, on, an, audacious, ...        616      7
# 24  [The, following, excerpt, is, from, Nicolette,...       1928      7
# 25  [Ed., note:, This, piece, was, originally, pub...        984      7

# %%
df['month'] = df.date.dt.month
df['year'] = df.date.dt.year

# %%
toplot = df.groupby(['year', 'month']).agg({'title':'count', 'num_words':'mean', 'date':'min'})

# %%
fig = px.scatter(toplot, x='date', y='title', size='num_words', 
           labels = {'date':'Date', 'title':'Number of Articles'},
           title = 'Figure 3')

fig.update_layout(
    font_family = 'Times New Roman',
    font_color = 'black'

)
# Out:
# <div>                            <div id="00047e50-0f5d-4729-bc57-89d257eed632" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00047e50-0f5d-4729-bc57-89d257eed632")) {                    Plotly.newPlot(                        "00047e50-0f5d-4729-bc57-89d257eed632",                        [{"hovertemplate":"Date=%{x}<br>Number of Articles=%{y}<br>num_words=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[648.0,3331.5,3811.0,717.0,222.0,1053.0,788.0,459.0,2237.0,203.0,932.0,3962.5,1140.0,1549.0,3017.5,4797.0,5079.5,1684.2,2191.0,1066.0192307692307,1181.0,1937.888888888889,1035.7241379310344,1120.8064516129032,978.2,1003.1176470588235,1096.7411167512691,976.126582278481,958.4368932038835,960.9916666666667,1219.7215189873418,1264.1637931034484,1293.7692307692307,1317.0,1252.9315068493152,1472.7522935779816,1753.4383561643835,1767.870588235294,1666.2727272727273,1719.3846153846155,1836.6451612903227,1374.4963503649635,1481.275,1604.923076923077,1346.6153846153845,1617.6319444444443,1336.8309859154929,1397.850267379679,1525.6586826347304,1465.9303797468353,1287.9528795811518,1226.6038961038962,1084.609271523179,1267.6225490196077,1334.240506329114,1381.5621890547263,2054.3135135135135,1161.927536231884,1337.4551282051282,1180.8434343434344,1231.6170212765958,1274.8373205741627,1237.938775510204,1256.7514792899408,1130.1149425287356,1815.9030837004404,1206.9583333333333,1217.1333333333334,1336.0848214285713,1131.323383084577,1091.3468468468468,1136.1826625386998,1104.016304347826,1099.9251101321586,1205.1818181818182,1385.0172413793102,1079.8290598290598,1300.5116279069769,1231.8791208791208,1045.3950617283951,1137.7305699481865,1224.287234042553,1165.6060606060605,1195.5,1391.617924528302,1201.3902439024391,1616.7037037037037,1493.3333333333333,1634.703910614525,1548.137254901961,1595.409090909091,1426.0620689655173,1847.9809523809524,1575.4007782101166,1597.4952380952382,1587.1352941176472,1735.6684782608695,1437.605633802817,1484.7874396135267,1391.608888888889,1591.975845410628,1447.0208333333333,1661.0157068062827,1343.4031413612565,1362.639175257732,1402.1059322033898,1538.1659751037344,1420.604347826087,1505.0103626943005,1430.993710691824,1514.462765957447,1509.6914285714286,1898.783464566929,1602.032,1460.0495495495495,1304.872950819672,1098.3781512605042,1310.3191489361702,1611.9757575757576,1541.2307692307693,1307.939393939394,2071.4956896551726,1533.1162790697674,1742.3657142857144,1527.99,1561.2814371257484,1443.3863636363637,1361.4585635359117,1472.0877192982457,1525.2166666666667,1147.3529411764705,1367.6736842105263,1360.7314285714285,1292.835,2201.983240223464,1535.7888888888888,1506.6610169491526,1407.344262295082,1570.065868263473,1502.538860103627,1880.2884615384614,1872.5868263473053,1263.090909090909,1242.4060606060607,1571.3071895424837,1330.414201183432,1165.2147239263804,1747.2251655629138,1515.7748344370862,1538.7194244604316,1566.355072463768,1570.212765957447,1645.9194630872482,1723.0245398773006,1748.516129032258,1693.6689655172413,1712.9556962025317,1661.0075187969924,1571.7935483870967,1731.6363636363637,2663.188311688312,1767.105633802817,1727.939393939394,2015.442857142857,1779.7357142857143,1496.463768115942,1647.4705882352941,1928.7291666666667,1868.5933333333332,1824.9448818897638,2095.464285714286,1572.1560283687943,1581.6371681415928,2082.527777777778,1933.4083333333333,2022.8716216216217,1876.186567164179,1911.3082191780823,1811.8910891089108,1862.675,1859.9527027027027,1579.6762589928057,1584.590909090909,2492.358778625954,1784.4224137931035,1855.2824427480916,1955.7610619469026,2183.3172413793104,1874.8620689655172,2079.9338842975208,1830.0629921259842,2904.887931034483,2098.424,2138.7833333333333,1798.9256198347107,1670.7 ...

# %% [markdown]
# ### Updating the Resilience Dataset to Include Through 2021

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Create a list of urls (one for each page in latest-articles)
pagelist = ['https://www.resilience.org/latest-articles/page/' + str(p) for p in range(1, 200)]

# %%
# Function that lists the urls of the 12 articles presented on a given page
def list_articles(url):
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    return [h2.find('a')['href'] for h2 in soup.find_all("h2", {'class':'post-title'})]

# %%
# Create a headers object - this step avoids errors by telling the webpage where the request is coming from
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36'
referer = 'https://www.resilience.org/latest-articles/'
headers = {'User-Agent': user_agent, 'referer':referer}

# %%
requests.get('https://en.wikipedia.org/wiki/Main_Page')
# Out:
# <Response [200]>

# %%
urls = []
for page in pagelist:
    urls = urls + list_articles(page)

# %%
data = [scrape_article(url) for url in urls]
new = pd.concat(data)

# %%
new
# Out:
#                                                   url  \
# 0   https://www.resilience.org/stories/2022-02-06/...
# 0   https://www.resilience.org/stories/2022-02-04/...
# 0   https://www.resilience.org/stories/2022-02-04/...
# 0   https://www.resilience.org/stories/2022-02-04/...
# 0   https://www.resilience.org/stories/2022-02-04/...
# ..                                                ...
# 0   https://www.resilience.org/stories/2020-04-16/...
# 0   https://www.resilience.org/stories/2020-04-15/...
# 0   https://www.resilience.org/stories/2020-04-15/...
# 0   https://www.resilience.org/stories/2020-04-15/...
# 0   https://www.resilience.org/stories/2020-04-15/...
#
#                                                 title              date  \
# 0   Increased U.S. natural gas exports = higher U....  February 6, 2022
# 0   Ecological Civilisation: Beyond Consumerism an...  February 4, 2022
# 0            Growing community in vacant Chicago lots  February 4, 2022
# 0   Does renewable energy threaten efforts to cons...  February 4, 2022
# 0   Túmin: the alternative currency rebuilding com...  February 4, 2022
# ..                                                ...               ...
# 0     COVID-19 and the Death of Market Fundamentalism    April 16, 2020
# 0                    In Praise of Short Supply Chains    April 15, 2020
# 0   Climate Change Won’t Stop for the Coronavirus ...    April 15, 2020
# 0                         Open and Answered Questions    April 15, 2020
# 0   Trump’s Coronavirus Playbook is the Same One h...    April 15, 2020
#
#                author                                               text
# 0           Kurt Cobb  Few people noticed when energy reporters wrote...
# 0    Samuel Alexander  This is the introduction to the Ecological Civ...
# 0     Jordyn Harrison  From 100 feet in th­­e air, the parcel at 500 ...
# 0   Sebastian Dunnett  The world is facing a climate and ecological c...
# 0        Mattha Busby  In southern Mexico, Itzel Castro sits behind t...
# ..                ...                                                ...
# 0        Paul Gilding  On top of the countless human tragedies, there...
# 0     Francesca Price  As the coronavirus pandemic affects every area...
# 0   Abrahm Lustgarten  The next several months could bring hurricanes...
# 0        Chris Nelder  Your browser does not support the audio elemen...
# 0           Dan Reich  There is a consistent pattern to how President...
#
# [2388 rows x 5 columns]

# %%
# Function that scrapes an individual article
def scrape_article(url):
    try:
        page = requests.get(url, headers=headers)
        soup = BeautifulSoup(page.text, 'html.parser')

        title, author, date, text = 'None', 'None', 'None', 'None'

        try:
            post_content = soup.find("section", {"class":'post-content'})
            text = ' '.join([p.text.replace('\n', ' ') \
                                   .replace('\xa0' , ' ') \
                                   .replace('â€™', "'") for p in post_content.find_all('p') if len(p.text) > 0])
        except:
            pass

        try:
            title = soup.find('h1', {"class":"post-title"}).text
        except:
            pass
        
        try:
            date = soup.find("li", {"class":'post-date'}).text
        except:
            pass
        
        try:
            author = soup.find("span", {"class":"featured-image-credit"}).find("a").text
        except:
            pass

        return pd.DataFrame({'url':[url], 'title':[title], 'date':[date], 'author':[author], 'text':[text]})
    except:
        print("Failure to scrape: " + url)

# %%
df[df.date == df.date.max()]
# Out:
#                                                  url  \
# 0  https://www.resilience.org/stories/2021-07-16/...
# 1  https://www.resilience.org/stories/2021-07-16/...
# 2  https://www.resilience.org/stories/2021-07-16/...
#
#                                                title       date  \
# 0  Elinor Ostrom’s Essential Lessons for Collecti... 2021-07-16
# 1  No Time for Castles: From Closed to Open Democ... 2021-07-16
# 2                              Greed and Its Offsets 2021-07-16
#
#              author                                               text  \
# 0      Erik Nordman  The Uncommon Knowledge of Elinor Ostrom by Eri...
# 1  Hélène Landemore  For proponents of deliberative democracy, toda...
# 2     Simon Fairlie  Farmland shouldn’t be used to expiate the carb...
#
#                                            text_list  num_words
# 0  [The, Uncommon, Knowledge, of, Elinor, Ostrom,...       1267
# 1  [For, proponents, of, deliberative, democracy,...       2922
# 2  [Farmland, shouldn’t, be, used, to, expiate, t...       3965

# %%
new_trim = new[new.date > df.date.max()]

# %%
final = pd.concat([df, new])

# %%
final.to_pickle('../Data/Resilience/final.pkl')

# %%
new['date'] = pd.to_datetime(new.date)

# %%
new.iloc[:2500, :].head()
# Out:
#                                                  url  \
# 0  https://www.resilience.org/stories/2022-02-06/...
# 0  https://www.resilience.org/stories/2022-02-04/...
# 0  https://www.resilience.org/stories/2022-02-04/...
# 0  https://www.resilience.org/stories/2022-02-04/...
# 0  https://www.resilience.org/stories/2022-02-04/...
#
#                                                title       date  \
# 0  Increased U.S. natural gas exports = higher U.... 2022-02-06
# 0  Ecological Civilisation: Beyond Consumerism an... 2022-02-04
# 0           Growing community in vacant Chicago lots 2022-02-04
# 0  Does renewable energy threaten efforts to cons... 2022-02-04
# 0  Túmin: the alternative currency rebuilding com... 2022-02-04
#
#               author                                               text
# 0          Kurt Cobb  Few people noticed when energy reporters wrote...
# 0   Samuel Alexander  This is the introduction to the Ecological Civ...
# 0    Jordyn Harrison  From 100 feet in th­­e air, the parcel at 500 ...
# 0  Sebastian Dunnett  The world is facing a climate and ecological c...
# 0       Mattha Busby  In southern Mexico, Itzel Castro sits behind t...
